# %% [markdown]
# # Trabalho 2 – Análise Estrutural de Redes Urbanas
# ### Disciplina: Estrutura de Dados II (DCA3702)
#
# **Região analisada:** Natal, Rio Grande do Norte, Brasil
# **Ferramentas:** OSMnx, NetworkX, Matplotlib, Seaborn
#
# ---
#
# ## Estrutura do Notebook
#
# Este notebook contém o trabalho original e **cinco abordagens alternativas** que ampliam a análise:
#
# | # | Abordagem | Descrição |
# |---|---|---|
# | 0 | **Original** | Análise base com métricas obrigatórias |
# | 1 | **Comparação entre Bairros** | Análise estrutural comparativa entre regiões de Natal |
# | 2 | **Vulnerabilidade da Rede** | Simulação de ataques direcionados vs. aleatórios |
# | 3 | **Cruzamento com POIs** | Sobreposição de hubs com pontos de interesse urbano |
# | 4 | **Centralidade Ponderada** | Betweenness e closeness com pesos reais de comprimento e velocidade |
# | 5 | **Dashboard Comparativo** | Visualização consolidada de todas as métricas |

# %%
# !pip install osmnx networkx matplotlib nxviz
# Out:
# Requirement already satisfied: osmnx in /home/felix/anaconda3/lib/python3.13/site-packages (2.1.0)
# Requirement already satisfied: networkx in /home/felix/anaconda3/lib/python3.13/site-packages (3.5)
# Requirement already satisfied: matplotlib in /home/felix/anaconda3/lib/python3.13/site-packages (3.10.6)
# Requirement already satisfied: nxviz in /home/felix/anaconda3/lib/python3.13/site-packages (0.7.6)
# Requirement already satisfied: geopandas>=1.0.1 in /home/felix/anaconda3/lib/python3.13/site-packages (from osmnx) (1.1.3)
# Requirement already satisfied: numpy>=1.24 in /home/felix/anaconda3/lib/python3.13/site-packages (from osmnx) (2.3.5)
# Requirement already satisfied: pandas>=1.5 in /home/felix/anaconda3/lib/python3.13/site-packages (from osmnx) (2.3.3)
# Requirement already satisfied: requests>=2.30 in /home/felix/anaconda3/lib/python3.13/site-packages (from osmnx) (2.32.5)
# Requirement already satisfied: shapely>=2.0 in /home/felix/anaconda3/lib/python3.13/site-packages (from osmnx) (2.1.2)
# Requirement already satisfied: contourpy>=1.0.1 in /home/felix/anaconda3/lib/python3.13/site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /home/felix/anaconda3/lib/python3.13/site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /home/felix/anaconda3/lib/python3.13/site-packages (from matplotlib) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/felix/anaconda3/lib/python3.13/site-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /home/felix/anaconda3/lib/python3.13/site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in /home/felix/anaconda3/lib/python3.13/site-packages (from matplotlib) (12.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/felix/anaconda3/lib/python3.13/site-packages (from matplotlib) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /home/felix/anaconda3/lib/python3.13/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: more-itertools>=8.6.0 in /home/felix/anaconda3/lib/python3.13/site-packages (from nxviz) (10.8.0)
# Requirement already satisfied: palettable>=3.3.0 in /home/felix/anaconda3/lib/python3.13/site-packages (from nxviz) (3.3.3)
# Requirement already satisfied: seaborn>=0.11.1 in /home/felix/anaconda3/lib/python3.13/site-packages (from nxviz) (0.13.2)
# Requirement already satisfied: setuptools in /home/felix/anaconda3/lib/python3.13/site-packages (from nxviz) (80.9.0)
# Requirement already satisfied: pyogrio>=0.7.2 in /home/felix/anaconda3/lib/python3.13/site-packages (from geopandas>=1.0.1->osmnx) (0.12.1)
# Requirement already satisfied: pyproj>=3.5.0 in /home/felix/anaconda3/lib/python3.13/site-packages (from geopandas>=1.0.1->osmnx) (3.7.2)
# Requirement already satisfied: pytz>=2020.1 in /home/felix/anaconda3/lib/python3.13/site-packages (from pandas>=1.5->osmnx) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /home/felix/anaconda3/lib/python3.13/site-packages (from pandas>=1.5->osmnx) (2025.2)
# Requirement already satisfied: certifi in /home/felix/anaconda3/lib/python3.13/site-packages (from pyogrio>=0.7.2->geopandas>=1.0.1->osmnx) (2025.11.12)
# Requirement already satisfied: six>=1.5 in /home/felix/anaconda3/lib/python3.13/site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/felix/anaconda3/lib/python3.13/site-packages (from requests>=2.30->osmnx) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /home/felix/anaconda3/lib/python3.13/site-packages (from requests>=2.30->osmnx) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/felix/anaconda3/lib/python3.13/site-packages (from requests>=2.30->osmnx) (2.5.0)

# %%
import networkx as nx
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import matplotlib.colors as mcolors
import numpy as np
import seaborn as sns
import pandas as pd
import osmnx as ox
import warnings

warnings.filterwarnings('ignore')

# Configuração visual padrão
sns.set_theme(style='whitegrid', palette='muted')
plt.rcParams['figure.dpi'] = 120

print('Bibliotecas carregadas com sucesso!')
# Out:
# Bibliotecas carregadas com sucesso!

# %%
# Inicializando com a Zona Norte de Natal-RNZona Norte,Natal
place = "Santa Cruz, Rio Grande do Norte, Brazil"

G = ox.graph_from_place(place, network_type="drive")

print("Carrendando da Zona Norte de Natal\n")
print(G)
print(f"Número de nós: {G.number_of_nodes()}")
print(f"Número de arestas: {G.number_of_edges()}")
# Out:
# Carrendando da Zona Norte de Natal
#
# MultiDiGraph with 1984 nodes and 5346 edges
# Número de nós: 1984
# Número de arestas: 5346

# %%
# ============================================================
# Conversão: MultiDiGraph → Graph (não-direcionado)
# ------------------------------------------------------------
# CORREÇÃO: o grafo original era criado como nx.DiGraph(), o que é
# DIRECIONADO. core_number() e k_core() exigem grafo NÃO-DIRECIONADO.
# Usamos nx.Graph() e copiamos nós com todos os atributos originais
# (incluindo 'x'/'y' = longitude/latitude do OSMnx) para preservar
# a geolocalização na exportação.
# ============================================================

G_undirected = nx.Graph()

# Copiar nós preservando TODOS os atributos (inclusive x, y, lat, lon)
for node, data in G.nodes(data=True):
    G_undirected.add_node(node, **data)

# Copiar arestas sem duplicar (Graph já trata isso, mas mantemos a verificação)
for u, v, data in G.edges(data=True):
    if not G_undirected.has_edge(u, v):
        G_undirected.add_edge(u, v, **data)

# Remover self-loops
G_undirected.remove_edges_from(nx.selfloop_edges(G_undirected))

# Confirma que é não-direcionado
print(f"Tipo do grafo   : {type(G_undirected).__name__}  ← deve ser 'Graph'")
print(f"Nós             : {G_undirected.number_of_nodes()}")
print(f"Arestas         : {G_undirected.number_of_edges()}")

# Verifica presença de coordenadas nos nós
amostra = list(G_undirected.nodes(data=True))[:1]
no_id, no_data = amostra[0]
print(f"\nAtributos de um nó de exemplo (ID={no_id}):")
for k, v in no_data.items():
    print(f"  {k}: {v}")
# Out:
# Grafo convertido:
#
# Nós: 1984
# Arestas: 5310

# %%
#Grau dos Nós e Identificação de Hubs
degree_dict = dict(G_undirected.degree())

# Top 10 hubs por grau
top_degree = sorted(degree_dict.items(), key=lambda x: x[1], reverse=True)[:10]
print("Top 10 nós por grau (hubs):")
for rank, (node, deg) in enumerate(top_degree, 1):
    print(f"  {rank:2}. Nó {node} → grau {deg}")
# Out:
# Top 10 nós por grau (hubs):
#    1. Nó 3964693509 → grau 12
#    2. Nó 3964715642 → grau 10
#    3. Nó 314993294 → grau 8
#    4. Nó 1828181337 → grau 8
#    5. Nó 2837621816 → grau 8
#    6. Nó 2837621823 → grau 8
#    7. Nó 2837621824 → grau 8
#    8. Nó 2837621832 → grau 8
#    9. Nó 2837621850 → grau 8
#   10. Nó 2837621855 → grau 8

# %%
# Distribuição de Grau
degrees = list(degree_dict.values())

pfig, axes = plt.subplots(1, 2, figsize=(14, 5))

# Histograma linear
axes[0].hist(degrees, bins=30, color='steelblue', edgecolor='white', alpha=0.85)
axes[0].set_title('Distribuição de Grau (escala linear)', fontsize=13)
axes[0].set_xlabel('Grau')
axes[0].set_ylabel('Frequência')
axes[0].axvline(np.mean(degrees), color='red', linestyle='--', label=f'Média: {np.mean(degrees):.2f}')
axes[0].legend()

# Histograma log-log (revela lei de potência)
axes[1].hist(degrees, bins=30, color='coral', edgecolor='white', alpha=0.85)
axes[1].set_yscale('log')
axes[1].set_xscale('log')
axes[1].set_title('Distribuição de Grau (escala log-log)', fontsize=13)
axes[1].set_xlabel('Grau (log)')
axes[1].set_ylabel('Frequência (log)')

plt.tight_layout()
plt.savefig('distribuicao_grau.png', bbox_inches='tight')
plt.show()

print(f"Grau médio   : {np.mean(degrees):.2f}")
print(f"Grau mediano : {np.median(degrees):.2f}")
print(f"Grau máximo  : {max(degrees)}")
# Out:
# Grau médio   : 5.35
# Grau mediano : 6.00
# Grau máximo  : 12

# %%
# Criar o  betweenness
print("Calculando betweenness (aproximado)...")
betweenness = nx.betweenness_centrality(G_undirected, k=500, normalized=True, seed=42)

top_betweenness = sorted(betweenness.items(), key=lambda x: x[1], reverse=True)[:10]
print("\nTop 10 nós por betweenness:")
for rank, (node, val) in enumerate(top_betweenness, 1):
    print(f"  {rank:2}. Nó {node} → {val:.6f}")
# Out:
# Calculando betweenness (aproximado)...
#
# Top 10 nós por betweenness:
#    1. Nó 7428327102 → 0.155582
#    2. Nó 7410672473 → 0.142622
#    3. Nó 7413519201 → 0.135633
#    4. Nó 7413476027 → 0.134469
#    5. Nó 314993255 → 0.130195
#    6. Nó 5233567955 → 0.125180
#    7. Nó 3964616875 → 0.122811
#    8. Nó 7414103395 → 0.121193
#    9. Nó 3964720268 → 0.119983
#   10. Nó 314993252 → 0.118261

# %%
# Criar o  closeness
print("Calculando closeness centrality...")
closeness = nx.closeness_centrality(G_undirected)

top_closeness = sorted(closeness.items(), key=lambda x: x[1], reverse=True)[:10]
print("\nTop 10 nós por closeness:")
for rank, (node, val) in enumerate(top_closeness, 1):
    print(f"  {rank:2}. Nó {node} → {val:.6f}")
# Out:
# Calculando closeness centrality...
#
# Top 10 nós por closeness:
#    1. Nó 7428327102 → 0.048944
#    2. Nó 7429003086 → 0.048682
#    3. Nó 3964616875 → 0.048651
#    4. Nó 3964720257 → 0.048497
#    5. Nó 7436661174 → 0.048382
#    6. Nó 3964655751 → 0.048349
#    7. Nó 3964720259 → 0.048312
#    8. Nó 3964694000 → 0.048235
#    9. Nó 7428559181 → 0.048200
#   10. Nó 7428559176 → 0.048154

# %%
# ============================================================
# K-Core Decomposition
# ------------------------------------------------------------
# nx.core_number() e nx.k_core() exigem grafo não-direcionado.
# Funcionam corretamente agora que G_undirected é nx.Graph().
# ============================================================

core_number = nx.core_number(G_undirected)
max_core = max(core_number.values())

k_core_graph = nx.k_core(G_undirected, k=max_core)

print(f"Maior core number (k-max): {max_core}")
print(f"Nós no k-core máximo     : {k_core_graph.number_of_nodes()}")
print(f"Arestas no k-core máximo : {k_core_graph.number_of_edges()}")
print(f"\nDistribuição dos core numbers:")

core_counts = pd.Series(core_number.values()).value_counts().sort_index()
print(core_counts)
# Out:
# Maior core number (k-max): 4
# Nós no k-core máximo     : 1558
# Arestas no k-core máximo : 4420
#
# Distribuição dos core numbers:
# 2     352
# 3      74
# 4    1558
# Name: count, dtype: int64

# %%
# ============================================================
# Adição de Métricas e Exportação para Gephi
# ------------------------------------------------------------
# CORREÇÕES aplicadas:
#
# 1. A limpeza dos atributos dos nós PRESERVA 'x' e 'y'
#    (longitude e latitude no padrão OSMnx) explicitamente,
#    evitando a remoção acidental de coordenadas.
#
# 2. Atributos com valor None são convertidos para string vazia
#    em vez de removidos, evitando perda silenciosa de dados.
#
# 3. Listas são convertidas para string JSON para compatibilidade
#    com GraphML sem perder informação (ex: 'lanes': [2, 2]).
#
# 4. Usamos nx.write_graphml com verificação de tipos estrita.
#    ox.save_graphml exporta o MultiDiGraph original (G), enquanto
#    nx.write_graphml exporta G_undirected com as métricas calculadas.
#    Ambos os arquivos são gerados para uso complementar no Gephi.
#
# 5. Mensagem de print corrigida para refletir o nome real do arquivo.
# ============================================================

# Adicionar métricas calculadas como atributos dos nós
nx.set_node_attributes(G_undirected, degree_dict,  "degree")
nx.set_node_attributes(G_undirected, betweenness,  "betweenness")
nx.set_node_attributes(G_undirected, closeness,    "closeness")
nx.set_node_attributes(G_undirected, core_number,  "core_number")

# --- Limpeza das arestas ---
# GraphML não suporta objetos Python complexos (Shapely geometry, listas).
# Convertemos listas para string e removemos geometrias.
for u, v, data in G_undirected.edges(data=True):
    keys_remover = []
    keys_converter = {}
    for key, value in data.items():
        if key == 'geometry':               # Shapely → remover
            keys_remover.append(key)
        elif isinstance(value, list):       # lista → string JSON
            keys_converter[key] = str(value)
        elif value is None:                 # None → string vazia
            keys_converter[key] = ''
        elif not isinstance(value, (str, int, float, bool)):
            keys_remover.append(key)        # outros tipos complexos → remover
    for key in keys_remover:
        del data[key]
    data.update(keys_converter)

# --- Limpeza dos nós ---
# ATENÇÃO: 'x' (longitude) e 'y' (latitude) são floats e são PRESERVADOS.
# Apenas tipos realmente incompatíveis com GraphML são removidos.
COORDENADAS = {'x', 'y', 'lon', 'lat'}  # sempre preservar

for node, data in G_undirected.nodes(data=True):
    keys_remover = []
    keys_converter = {}
    for key, value in data.items():
        if key in COORDENADAS:              # coordenadas: nunca remover
            continue
        elif isinstance(value, list):       # lista → string JSON
            keys_converter[key] = str(value)
        elif value is None:                 # None → string vazia
            keys_converter[key] = ''
        elif not isinstance(value, (str, int, float, bool)):
            keys_remover.append(key)
    for key in keys_remover:
        del data[key]
    data.update(keys_converter)

# --- Exportação ---
NOME_ARQUIVO = 'Santa-Cruz.graphml'

# Arquivo principal: G_undirected com métricas + coordenadas
nx.write_graphml(G_undirected, NOME_ARQUIVO)
print(f"Arquivo '{NOME_ARQUIVO}' exportado com sucesso!")
print(f"  → Nós   : {G_undirected.number_of_nodes()}")
print(f"  → Arestas: {G_undirected.number_of_edges()}")

# Verificação: confirma que lat/lon foram preservados
amostra_no = list(G_undirected.nodes(data=True))[0]
print(f"\nVerificação de coordenadas no nó {amostra_no[0]}:")
print(f"  x (longitude) = {amostra_no[1].get('x', 'NÃO ENCONTRADO')}")
print(f"  y (latitude)  = {amostra_no[1].get('y', 'NÃO ENCONTRADO')}")
# Out:
# Arquivo 'ZN_Natal.graphml' exportado com sucesso!
